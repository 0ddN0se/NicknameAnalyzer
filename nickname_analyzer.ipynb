# %%
import json
from collections import Counter
import matplotlib.pyplot as plt
from src.app.core.nicknameanalyser import NicknameAnalyzer

# %%
analyzer = NicknameAnalyzer('src/data/dataset/nicknames.json')

# %%
print("Частотное распределение типов никнеймов:")
print(analyzer.get_type_distribution())
analyzer.visualize_type_distribution()
# Out:
# Частотное распределение типов никнеймов:
# Counter({'составной': 129, 'неопределенный': 57, 'номинативный': 40})

# %%
print("\nТипы никнеймов по полу:")
print(analyzer.get_gender_based_distribution())
analyzer.visualize_gender_distribution()
# Out:
# Типы никнеймов по полу:
# {'male': Counter({'составной': 66, 'неопределенный': 35, 'номинативный': 12}), 'female': Counter({'составной': 63, 'номинативный': 28, 'неопределенный': 22})}

# %%
print("\nТипы никнеймов по образованию:")
print(analyzer.get_education_based_distribution())
analyzer.visualize_education_distribution()
# Out:
# Типы никнеймов по образованию:
# {'humanitarian': Counter({'составной': 5, 'неопределенный': 4, 'номинативный': 4}), 'technical': Counter({'составной': 62, 'неопределенный': 26, 'номинативный': 22}), 'scientific': Counter({'составной': 62, 'неопределенный': 27, 'номинативный': 14})}
